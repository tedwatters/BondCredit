# %% [markdown]
# # Data Validation/ Limitations

# %% [markdown]
# # 1 - Determine how many issuances do not have ratings data

# %% [markdown]
# # 2 - Determine scope of FISD Data.
#
# Specific exclusions:
#
# https://wrds-www.wharton.upenn.edu/documents/740/Not_Part_of_FISD_Coverage.pdf

# %%
import MySQLdb
import pandas as pd

df = pd.read_sql('main_n_index', 'mysql+mysqldb://root:password@localhost/bond_credit')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/encodings/cp1252.py in decode(self, input, errors)
#      13
# ---> 14     def decode(self,input,errors='strict'):
#      15         return codecs.charmap_decode(input,errors,decoding_table)
#
# KeyboardInterrupt:
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-db5acecddd9f> in <module>
#       2 import pandas as pd
#       3
# ----> 4 df = pd.read_sql('main_n_index', 'mysql+mysqldb://root:password@localhost/bond_credit')
#       5
#       6 s = df.groupby('COMPLETE_CUSIP').N_INDEX.agg(lambda x:len(x.unique()))
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
# ...

# %%
s = df.groupby('COMPLETE_CUSIP').N_INDEX.agg(lambda x:len(x.unique()))
pd.value_counts(s).plot(kind="bar")
